# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. Flávio Martins
#
# ### Grupo GG
# <dl>
#     <dt>35 horas (33.3%)</dt>
#     <dd>ist1106204 João  Tomás de Almeida Santos Antunes Gomes</dd>
#     <dt>35 horas (33.3%)</dt>
#     <dd>ist1106001 Manuel Soares Eleutério da Silva</dd>
#     <dt>35 horas (33.3%)</dt>
#     <dd>ist1106194 Sofia Dinis Pinto Piteira</dd>
# <dl>

# %%
# %load_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://postgres:postgres@postgres/saude
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql+psycopg://postgres:***@postgres/saude'

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
#
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
# DROP TABLE IF EXISTS horario CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns VARCHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
#
# CREATE TABLE horario(
#     data DATE NOT NULL,
# 	hora TIME NOT NULL,
#     PRIMARY KEY (data, hora)
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# -- (RI-1)
# CREATE OR REPLACE FUNCTION check_time() RETURNS TRIGGER AS $$
#     BEGIN
#         IF NOT (
#             (NEW.hora >= '08:00:00' AND NEW.hora < '13:30:00' AND date_part('minute', NEW.hora) IN (0, 30)) OR
#             (NEW.hora >= '14:00:00' AND NEW.hora < '19:30:00' AND date_part('minute', NEW.hora) IN (0, 30))
#         ) THEN
#                 RAISE EXCEPTION 'Horário de consulta inválido. As consultas são a horas exatas ou meia-hora no horário 8-13h e 14-19h.';
#         END IF;
#         RETURN NEW;
#     END
# $$ LANGUAGE plpgsql;
# CREATE OR REPLACE TRIGGER check_time_trigger Before INSERT ON Consulta
#   FOR EACH ROW EXECUTE FUNCTION check_time();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# -- (RI-2)
# CREATE OR REPLACE FUNCTION consulta_no_self_medico()
# RETURNS TRIGGER AS $$
# BEGIN
#     -- Verificar se o médico está a tentar consultar-se a si mesmo
#     IF NEW.nif = NEW.ssn THEN
#         RAISE EXCEPTION 'Um médico não se pode consultar a si próprio.';
#     END IF;
#
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE TRIGGER consulta_no_self_medico_trigger
# BEFORE INSERT ON consulta
# FOR EACH ROW
# EXECUTE FUNCTION consulta_no_self_medico();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# -- (RI-3)
# CREATE OR REPLACE FUNCTION consulta_clinica_dia_semana()
# RETURNS TRIGGER AS $$
# DECLARE
#     dia_semana_consulta INTEGER;
#     dia_semana_trabalha INTEGER;
# BEGIN
#     -- Obter o dia da semana da data da consulta
#     dia_semana_consulta := EXTRACT(DOW FROM NEW.data);
#
#     -- Obter o dia da semana em que o médico trabalha na clínica
#     SELECT dia_da_semana INTO dia_semana_trabalha
#     FROM trabalha
#     WHERE nif = NEW.nif AND nome = NEW.nome AND dia_semana_consulta = dia_da_semana;
#
#     -- Verificar se o dia da semana da consulta coincide com o dia de trabalho do médico na clínica
#     IF dia_semana_consulta <> dia_semana_trabalha THEN
#         RAISE EXCEPTION 'O médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta.';
#     END IF;
#
#     RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE TRIGGER consulta_clinica_dia_semana_trigger
# BEFORE INSERT ON consulta
# FOR EACH ROW
# EXECUTE FUNCTION consulta_clinica_dia_semana();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta web/arquivos e a relação entre eles
#
# ...

# %% [markdown]
# ## 3. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano, mes, dia_do_mes* e *dia_da_semana*: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# -- CREATE MATERIALIZED VIEW ...
#
# -- Drop the existing materialized view if it exists
# DROP MATERIALIZED VIEW IF EXISTS historial_paciente;
#
# -- Create the materialized view
# CREATE MATERIALIZED VIEW historial_paciente AS
# SELECT
#     c.id,
#     c.ssn,
#     c.nif,
#     c.nome,
#     c.data,
#     EXTRACT(YEAR FROM c.data) AS ano,
#     EXTRACT(MONTH FROM c.data) AS mes,
#     EXTRACT(DAY FROM c.data) AS dia_do_mes,
#     EXTRACT(DOW FROM c.data) AS dia_da_semana,
#     SUBSTRING(cl.morada FROM '([^ ]+)$') AS localidade,
#     m.especialidade,
#     'observacao' AS tipo,
#     o.parametro AS chave,
#     o.valor
# FROM
#     consulta c
# JOIN
#     clinica cl ON c.nome = cl.nome
# JOIN
#     medico m ON c.nif = m.nif
# LEFT JOIN
#     observacao o ON c.id = o.id
#
# UNION ALL
#
# SELECT
#     c.id,
#     c.ssn,
#     c.nif,
#     c.nome,
#     c.data,
#     EXTRACT(YEAR FROM c.data) AS ano,
#     EXTRACT(MONTH FROM c.data) AS mes,
#     EXTRACT(DAY FROM c.data) AS dia_do_mes,
#     EXTRACT(DOW FROM c.data) AS dia_da_semana,
#     cl.morada AS localidade,
#     m.especialidade,
#     'receita' AS tipo,
#     r.medicamento AS chave,
#     r.quantidade AS valor
# FROM
#     consulta c
# JOIN
#     clinica cl ON c.nome = cl.nome
# JOIN
#     medico m ON c.nif = m.nif
# LEFT JOIN
#     receita r ON c.codigo_sns = r.codigo_sns;
# Out:
# 547995 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# -- SELECT ...
# WITH ortopedia_observacoes AS (
#     SELECT
#         hp.ssn,
#         hp.data,
#         hp.chave
#     FROM
#         historial_paciente hp
#     WHERE
#         hp.tipo = 'observacao'
#         AND hp.especialidade = 'Ortopedia'
# ),
#
# intervalos_temporais AS (
#     SELECT
#         ssn,
#         chave,
#         EXTRACT(EPOCH FROM MAX(data)) - EXTRACT(EPOCH FROM MIN(data)) AS max_intervalo
#     FROM
#         ortopedia_observacoes
#     GROUP BY
#         ssn, chave
# ),
#
# intervalo_maximo AS (
#     SELECT
#         MAX(max_intervalo) AS intervalo_maximo
#     FROM
#         intervalos_temporais
# ),
#
# pacientes_com_maior_intervalo AS (
#     SELECT
#         it.ssn,
#         it.max_intervalo
#     FROM
#         intervalos_temporais it
#     JOIN
#         intervalo_maximo im ON it.max_intervalo = im.intervalo_maximo
# )
#
# SELECT
#     DISTINCT p.ssn,
#     p.nome,
#     pcm.max_intervalo
# FROM
#     paciente p
# JOIN
#     pacientes_com_maior_intervalo pcm ON p.ssn = pcm.ssn;
# Out:
# 76 rows affected.
# +-------------+---------------------+---------------+
# |     ssn     |         nome        | max_intervalo |
# +-------------+---------------------+---------------+
# | 00023028483 |     Carolina Ana    |    60480000   |
# | 00175461688 |    Ramon Gustavo    |    60480000   |
# | 02620409309 |      Ines Laura     |    60480000   |
# | 02659797341 |     Eduarda Toni    |    60480000   |
# | 03658964315 |   Eduarda Vanessa   |    60480000   |
# | 09654493742 |      Luis Ramon     |    60480000   |
# | 10254747813 |   Rodrigo Arminda   |    60480000   |
# | 13224425792 |  Francisca Ricardo  |    60480000   |
# | 13226815494 |     Renata Fabio    |    60480000   |
# | 14588792316 |    Antonio Katia    |    60480000   |
# | 18221787386 |     Ramon Tiago     |    60480000   |
# | 19468663442 |    Manuela Andre    |    60480000   |
# | 20177270292 |     Diana Bruno     |    60480000   |
# | 21152262564 |   Beatriz Barbara   |    60480000   |
# | 22095467453 |    Beatriz Sergio   |    60480000   |
# | 22757080153 |     Sergio Katia    |    60480000   |
# | 24733148232 |     Kevin Vitor     |    60480000   |
# | 26086420589 |     Ursula Ines     |    60480000   |
# | 28098100532 | Elisabete Elisabete |    60480000   |
# | 28372015831 |    Edmundo Diana    |    60480000   |
# | 30077463165 | Sthefania Francisca |    60480000   |
# | 30269933776 |     Pedro Andre     |    60480000   |
# | 30971341882 |     Ramon Edgar     |    60480000   |
# | 31332935784 |      Pedro Hugo     |    60480000   |
# | 36416076165 |     Vitor Ramon     |    60480000   |
# | 36468731538 |    Catarina Pedro   |    60480000   |
# | 39485745479 |     Ana Antonio     |    60480000   |
# | 40191619284 |       Ze Dinis      |    60480000   |
# | 42307702229 |     Rafael Simao    |    60480000   |
# | 43611753611 |     Silvia Toni     |    60480000   |
# | 45257939643 |  Juliana Elisabete  |    60480000   |
# | 46060770694 |    Renata Fatima    |    60480000   |
# | 47528560055 |    Bruno Rafaela    |    60480000   |
# | 48321708592 |     Nuno Arminda    |    60480000   |
# | 49729103428 |      Sara Kevin     |    60480000   |
# | 51546625267 |    Danilo Liliana   |    60480000   |
# | 52449895841 |   Santiago Sandra   |    60480000   |
# | 54458784562 |    Manuela Marta    |    60480000   |
# | 56011226383 |    Edgar Barbara    |    60480000   |
# | 56232760117 |      Pedro Luis     |    60480000   |
# | 56336952217 |    Danilo Claudia   |    60480000   |
# | 57181827694 |    Leonor Ronaldo   |    60480000   |
# | 58649282156 |  Henrique Quintino  |    60480000   |
# | 59873195644 |     Marta Paulo     |    60480000   |
# | 60103129954 |   Gabriela Marcelo  |    60480000   |
# | 62329082469 |    Leonor Edmundo   |    60480000   |
# | 62924167983 |     Tomas Tiago     |    60480000   |
# | 63325288887 |     Pedra Tomas     |    60480000   |
# | 65406176757 |    Diana Quintino   |    60480000   |
# | 66759302089 |    Manuel Gabriel   |    60480000   |
# | 66833284927 |    Rodrigo Katia    |    60480000   |
# | 67414400741 |    Helena Gustavo   |    60480000   |
# | 68898063067 |    Beatriz Miguel   |    60480000   |
# | 69751340746 |      Andre Hugo     |    60480000   |
# | 70598884883 |    Juliana Edgar    |    60480000   |
# | 73132430081 |     Vitor Vitor     |    60480000   |
# | 75134098244 |   Francisco Samuel  |    60480000   |
# | 75172064464 |    Ines Francisca   |    60480000   |
# | 75788566656 |   Ricardo Arminda   |    60480000   |
# | 76274648342 |    Catarina Luis    |    60480000   |
# | 77086913387 |    Edmundo Xavier   |    60480000   |
# | 77234847715 |    Silvia Ricardo   |    60480000   |
# | 77803963962 |   Manuela Antonio   |    60480000   |
# | 78598659454 |      Rui Danilo     |    60480000   |
# | 79476586037 |     Ramon Nelson    |    60480000   |
# | 81102027160 |    Tiago Quintino   |    60480000   |
# | 82303260146 |     Carla Sofia     |    60480000   |
# | 82395412307 |    Lucas Santiago   |    60480000   |
# | 89277009822 |    Danilo Miguel    |    60480000   |
# | 90992487490 |     Paulo Diana     |    60480000   |
# | 92634949743 |    Liliana Simao    |    60480000   |
# | 94587136161 |  Francisco Tatiana  |    60480000   |
# | 94814510619 |     Ines Rafael     |    60480000   |
# | 97525639361 |     Hugo Helena     |    60480000   |
# | 98870472351 |  Elisabete Tatiana  |    60480000   |
# | 99585692405 |    Roberto Lucas    |    60480000   |
# +-------------+---------------------+---------------+

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante pelo menos doze meses consecutivos, em consultas de cardiologia.

# %%
# %%sql
# -- SELECT ...
# WITH MonthlyMedication AS (
#     SELECT
#         hp.ssn,
#         hp.chave AS medicamento,
#         hp.ano,
#         hp.mes
#     FROM
#         historial_paciente hp
#     WHERE
#         hp.tipo = 'receita'
#         AND hp.especialidade = 'Cardiologia'
#         AND (hp.ano * 12 + hp.mes) >= (EXTRACT(YEAR FROM CURRENT_DATE) * 12 + EXTRACT(MONTH FROM CURRENT_DATE) - 12)
#         AND (hp.ano * 12 + hp.mes) < (EXTRACT(YEAR FROM CURRENT_DATE) * 12 + EXTRACT(MONTH FROM CURRENT_DATE))
#     GROUP BY
#         hp.ssn, hp.chave, hp.ano, hp.mes
# ),
# ConsecutiveMonthlyMedication AS (
#     SELECT
#         ssn,
#         medicamento,
#         COUNT(DISTINCT ano * 12 + mes) AS meses_consecutivos
#     FROM
#         MonthlyMedication
#     GROUP BY
#         ssn, medicamento
#     HAVING
#         COUNT(DISTINCT ano * 12 + mes) = 12
# )
# SELECT DISTINCT
#     medicamento
# FROM
#     ConsecutiveMonthlyMedication;
# Out:
# 1 rows affected.
# +-------------+
# | medicamento |
# +-------------+
# | Paracetamol |
# +-------------+

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# WITH clinic_data AS (
#     SELECT
#         hp.chave AS medicamento,
#         hp.localidade,
#         hp.nome AS clinica,
#         NULL::INTEGER AS mes,
#         NULL::INTEGER AS dia_do_mes,
#         NULL::TEXT AS nome,
#         NULL::TEXT AS especialidade,
#         SUM(hp.valor) AS total_quantidade
#     FROM historial_paciente hp
#     JOIN medico m ON m.nif = hp.nif
#     WHERE tipo = 'receita' AND ano = 2023
#     GROUP BY GROUPING SETS((medicamento, hp.localidade), (medicamento, hp.localidade, hp.nome))
# ),
# date_data AS (
#     SELECT
#         hp.chave AS medicamento,
#         NULL::TEXT AS localidade,
#         NULL::TEXT AS clinica,
#         hp.mes,
#         hp.dia_do_mes,
#         NULL::TEXT AS nome,
#         NULL::TEXT AS especialidade,
#         SUM(hp.valor) AS total_quantidade
#     FROM historial_paciente hp
#     JOIN medico m ON m.nif = hp.nif
#     WHERE tipo = 'receita' AND ano = 2023
#     GROUP BY GROUPING SETS((medicamento,hp.mes), (medicamento,hp.mes, hp.dia_do_mes))
# ),
# medico_data AS (
#     SELECT
#         hp.chave AS medicamento,
#         NULL::TEXT AS localidade,
#         NULL::TEXT AS clinica,
#         NULL::INTEGER AS mes,
#         NULL::INTEGER AS dia_do_mes,
#         m.nome AS nome,
#         hp.especialidade,
#         SUM(hp.valor) AS total_quantidade
#     FROM historial_paciente hp
#     JOIN medico m ON m.nif = hp.nif
#     WHERE tipo = 'receita' AND ano = 2023
#     GROUP BY GROUPING SETS((medicamento,hp.especialidade), (medicamento,hp.especialidade, m.nome))
# )
# SELECT * FROM clinic_data
# UNION ALL
# SELECT * FROM date_data
# UNION ALL
# SELECT * FROM medico_data;
# Out:
# 2718 rows affected.
# +---------------+-------------------------------------------+------------------------------+------+------------+------+---------------+------------------+
# |  medicamento  |                 localidade                |           clinica            | mes  | dia_do_mes | nome | especialidade | total_quantidade |
# +---------------+-------------------------------------------+------------------------------+------+------------+------+---------------+------------------+
# |  Amoxicilina  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8413.0      |
# |  Amoxicilina  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8413.0      |
# |  Amoxicilina  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8467.0      |
# |  Amoxicilina  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8467.0      |
# |  Amoxicilina  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8615.0      |
# |  Amoxicilina  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8615.0      |
# |  Amoxicilina  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8557.0      |
# |  Amoxicilina  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8557.0      |
# |  Amoxicilina  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8345.0      |
# |  Amoxicilina  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8345.0      |
# | Atorvastatina |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8583.0      |
# | Atorvastatina |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8583.0      |
# | Atorvastatina |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8576.0      |
# | Atorvastatina |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8576.0      |
# | Atorvastatina | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8511.0      |
# | Atorvastatina | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8511.0      |
# | Atorvastatina |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8489.0      |
# | Atorvastatina |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8489.0      |
# | Atorvastatina | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8613.0      |
# | Atorvastatina | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8613.0      |
# |   Ibuprofeno  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8416.0      |
# |   Ibuprofeno  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8416.0      |
# |   Ibuprofeno  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8414.0      |
# |   Ibuprofeno  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8414.0      |
# |   Ibuprofeno  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8402.0      |
# |   Ibuprofeno  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8402.0      |
# |   Ibuprofeno  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8629.0      |
# |   Ibuprofeno  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8629.0      |
# |   Ibuprofeno  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8446.0      |
# |   Ibuprofeno  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8446.0      |
# |   Metformina  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8559.0      |
# |   Metformina  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8559.0      |
# |   Metformina  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8261.0      |
# |   Metformina  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8261.0      |
# |   Metformina  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8455.0      |
# |   Metformina  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8455.0      |
# |   Metformina  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8567.0      |
# |   Metformina  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8567.0      |
# |   Metformina  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8636.0      |
# |   Metformina  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8636.0      |
# |   Omeprazol   |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8558.0      |
# |   Omeprazol   |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8558.0      |
# |   Omeprazol   |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8510.0      |
# |   Omeprazol   |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8510.0      |
# |   Omeprazol   | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8590.0      |
# |   Omeprazol   | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8590.0      |
# |   Omeprazol   |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8555.0      |
# |   Omeprazol   |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8555.0      |
# |   Omeprazol   | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8573.0      |
# |   Omeprazol   | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8573.0      |
# |  Paracetamol  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |   Hospital Beatriz Angelo    | None |    None    | None |      None     |      8378.0      |
# |  Paracetamol  |  Largo Lua Cheia 9 4 1 2 - 4 7 8 Amadora  |             None             | None |    None    | None |      None     |      8378.0      |
# |  Paracetamol  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  | Clinica Sao Francisco Xavier | None |    None    | None |      None     |      8513.0      |
# |  Paracetamol  |   Praceta Encanto 5 4 8 8 - 1 6 5 Oeiras  |             None             | None |    None    | None |      None     |      8513.0      |
# |  Paracetamol  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |   Hospital de Santa Maria    | None |    None    | None |      None     |      8410.0      |
# |  Paracetamol  | Praceta Primavera 3 2 4 1 - 6 6 7 Cascais |             None             | None |    None    | None |      None     |      8410.0      |
# |  Paracetamol  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |     Hospital de Cascais      | None |    None    | None |      None     |      8501.0      |
# |  Paracetamol  |    Rua Sao Joao 9 9 8 4 - 7 2 3 Amadora   |             None             | None |    None    | None |      None     |      8501.0      |
# |  Paracetamol  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |       Hospital da Luz        | None |    None    | None |      None     |      8398.0      |
# |  Paracetamol  | Travessa Lua Cheia 5 8 0 8 - 8 0 6 Oeiras |             None             | None |    None    | None |      None     |      8398.0      |
# |  Amoxicilina  |                    None                   |             None             |  1   |     1      | None |      None     |      100.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     2      | None |      None     |      147.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     3      | None |      None     |      117.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     4      | None |      None     |       97.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     5      | None |      None     |      126.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     6      | None |      None     |       97.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     7      | None |      None     |      149.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     8      | None |      None     |      117.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     9      | None |      None     |      127.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     10     | None |      None     |      135.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     11     | None |      None     |      104.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     12     | None |      None     |      129.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     13     | None |      None     |      106.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     14     | None |      None     |      122.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     15     | None |      None     |      117.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     16     | None |      None     |      109.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     17     | None |      None     |      128.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     18     | None |      None     |      133.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     19     | None |      None     |      134.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     20     | None |      None     |      104.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     21     | None |      None     |      125.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     22     | None |      None     |      111.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     23     | None |      None     |      119.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     24     | None |      None     |      112.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     25     | None |      None     |       98.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     26     | None |      None     |      128.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     27     | None |      None     |       84.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     28     | None |      None     |      122.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     29     | None |      None     |      120.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     30     | None |      None     |      103.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |     31     | None |      None     |      124.0       |
# |  Amoxicilina  |                    None                   |             None             |  1   |    None    | None |      None     |      3644.0      |
# |  Amoxicilina  |                    None                   |             None             |  2   |     1      | None |      None     |      105.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     2      | None |      None     |      119.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     3      | None |      None     |      113.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     4      | None |      None     |      111.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     5      | None |      None     |      100.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     6      | None |      None     |      117.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     7      | None |      None     |      113.0       |
# |  Amoxicilina  |                    None                   |             None             |  2   |     8      | None |      None     |       99.0       |
# +---------------+-------------------------------------------+------------------------------+------+------------+------+---------------+------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# WITH ObservacoesMetricas AS (
#     SELECT
#         hp.chave AS parametro,
#         hp.valor,
#         hp.especialidade,
#         m.nome AS medico_nome,
#         hp.nome AS clinica_nome
#     FROM
#         historial_paciente hp
#     JOIN medico m ON hp.nif = m.nif
#     WHERE
#         hp.valor IS NOT NULL and hp.tipo = 'observacao'
# )
# SELECT
#     parametro,
#     especialidade,
#     medico_nome,
#     clinica_nome,
#     AVG(valor) AS media_valor,
#     STDDEV(valor) AS desvio_padrao_valor
# FROM
#     ObservacoesMetricas
# GROUP BY GROUPING SETS((parametro), (parametro, especialidade), (parametro, especialidade, medico_nome),(parametro, especialidade, medico_nome, clinica_nome));
# Out:
# 4940 rows affected.
# +-----------+---------------+---------------+------------------------------+--------------------+---------------------+
# | parametro | especialidade |  medico_nome  |         clinica_nome         |    media_valor     | desvio_padrao_valor |
# +-----------+---------------+---------------+------------------------------+--------------------+---------------------+
# |   Altura  |  Cardiologia  |  Kowi Adebola |       Hospital da Luz        | 41.92407407407408  |  27.318900932287672 |
# |   Altura  |  Cardiologia  |  Kowi Adebola |     Hospital de Cascais      | 44.51622641509433  |  28.774007316059986 |
# |   Altura  |  Cardiologia  |  Kowi Adebola |   Hospital de Santa Maria    | 54.85531250000001  |  32.14104510659781  |
# |   Altura  |  Cardiologia  |  Kowi Adebola |             None             | 46.84535714285714  |  29.633865486214983 |
# |   Altura  |  Cardiologia  |   Kowi Eshe   | Clinica Sao Francisco Xavier | 39.74888888888889  |  30.37420517263424  |
# |   Altura  |  Cardiologia  |   Kowi Eshe   |   Hospital Beatriz Angelo    | 46.42416666666667  |  32.636760773518546 |
# |   Altura  |  Cardiologia  |   Kowi Eshe   |     Hospital de Cascais      | 46.15296296296297  |  30.32231388527421  |
# |   Altura  |  Cardiologia  |   Kowi Eshe   |   Hospital de Santa Maria    | 63.17791666666667  |  22.79785840040524  |
# |   Altura  |  Cardiologia  |   Kowi Eshe   |             None             | 48.89907407407408  |  29.791547554242715 |
# |   Altura  |  Cardiologia  |   Kowi Lulu   | Clinica Sao Francisco Xavier | 46.114000000000004 |  28.833758613636785 |
# |   Altura  |  Cardiologia  |   Kowi Lulu   |   Hospital Beatriz Angelo    | 50.48666666666666  |  31.866976532663614 |
# |   Altura  |  Cardiologia  |   Kowi Lulu   |       Hospital da Luz        |  50.1521052631579  |  24.23934395402725  |
# |   Altura  |  Cardiologia  |   Kowi Lulu   |             None             | 48.923166666666674 |  28.200280771030837 |
# |   Altura  |  Cardiologia  |  Kowi Mandla  | Clinica Sao Francisco Xavier | 57.249545454545455 |  27.091411128370684 |
# |   Altura  |  Cardiologia  |  Kowi Mandla  |     Hospital de Cascais      | 55.97263157894736  |  28.176067781880473 |
# |   Altura  |  Cardiologia  |  Kowi Mandla  |             None             | 56.259285714285724 |   27.803148944627   |
# |   Altura  |  Cardiologia  |   Kowi Nyah   | Clinica Sao Francisco Xavier | 51.873999999999995 |  28.844775490605716 |
# |   Altura  |  Cardiologia  |   Kowi Nyah   |       Hospital da Luz        | 56.267575757575784 |  28.71100812736108  |
# |   Altura  |  Cardiologia  |   Kowi Nyah   |     Hospital de Cascais      | 51.30166666666668  |  30.209736305486995 |
# |   Altura  |  Cardiologia  |   Kowi Nyah   |   Hospital de Santa Maria    | 44.77421052631579  |  22.449356168889583 |
# |   Altura  |  Cardiologia  |   Kowi Nyah   |             None             |      51.8719       |  27.833154225335534 |
# |   Altura  |  Cardiologia  |   Kowi Penda  | Clinica Sao Francisco Xavier | 49.37368421052632  |  29.407319826847466 |
# |   Altura  |  Cardiologia  |   Kowi Penda  |   Hospital de Santa Maria    | 51.662083333333335 |  30.13350690046824  |
# |   Altura  |  Cardiologia  |   Kowi Penda  |             None             | 50.41980952380953  |  29.619712802487317 |
# |   Altura  |  Cardiologia  |   Kowi Talib  |   Hospital Beatriz Angelo    | 51.73583333333334  |  31.767309546090008 |
# |   Altura  |  Cardiologia  |   Kowi Talib  |       Hospital da Luz        | 51.60395833333333  |  27.77162348931494  |
# |   Altura  |  Cardiologia  |   Kowi Talib  |   Hospital de Santa Maria    | 55.35166666666666  |  23.858255507944268 |
# |   Altura  |  Cardiologia  |   Kowi Talib  |             None             | 52.38866666666666  |  27.911292354509072 |
# |   Altura  |  Cardiologia  |   Kowi Zola   | Clinica Sao Francisco Xavier | 36.608999999999995 |  25.887604410320847 |
# |   Altura  |  Cardiologia  |   Kowi Zola   |   Hospital Beatriz Angelo    | 44.769999999999996 |  29.484869679210043 |
# |   Altura  |  Cardiologia  |   Kowi Zola   |             None             | 41.56960784313725  |  28.150875578623435 |
# |   Altura  |  Cardiologia  |      None     |             None             | 50.12828729281765  |  28.82889581398714  |
# |   Altura  | Clinica Geral |  Adebola Eshe | Clinica Sao Francisco Xavier | 41.07481481481481  |  31.379317094394224 |
# |   Altura  | Clinica Geral |  Adebola Eshe |   Hospital Beatriz Angelo    | 49.49520000000001  |  34.77388413258816  |
# |   Altura  | Clinica Geral |  Adebola Eshe |     Hospital de Cascais      |       44.405       |  30.953132743983552 |
# |   Altura  | Clinica Geral |  Adebola Eshe |             None             | 44.95411764705883  |   32.3046787071782  |
# |   Altura  | Clinica Geral | Adebola Nkosi | Clinica Sao Francisco Xavier | 55.95214285714287  |  26.757962934858856 |
# |   Altura  | Clinica Geral | Adebola Nkosi |   Hospital Beatriz Angelo    | 49.70923076923077  |  28.513569100281682 |
# |   Altura  | Clinica Geral | Adebola Nkosi |   Hospital de Santa Maria    | 41.132272727272714 |  27.796177354829304 |
# |   Altura  | Clinica Geral | Adebola Nkosi |             None             |  49.5884347826087  |  28.144113110769048 |
# |   Altura  | Clinica Geral |  Adebola Nyah |   Hospital Beatriz Angelo    | 48.47106382978724  |  28.233352096107783 |
# |   Altura  | Clinica Geral |  Adebola Nyah |     Hospital de Cascais      |       53.214       |  33.97235058412247  |
# |   Altura  | Clinica Geral |  Adebola Nyah |             None             |  49.8868656716418  |  29.876391571949757 |
# |   Altura  | Clinica Geral | Adebola Penda | Clinica Sao Francisco Xavier |       55.684       |  31.35642278704636  |
# |   Altura  | Clinica Geral | Adebola Penda |   Hospital Beatriz Angelo    | 48.94688888888888  |  31.795685014724178 |
# |   Altura  | Clinica Geral | Adebola Penda |       Hospital da Luz        | 48.01714285714286  |  35.04582306474931  |
# |   Altura  | Clinica Geral | Adebola Penda |             None             | 50.79702380952379  |  31.983788204386308 |
# |   Altura  | Clinica Geral | Adebola Talib | Clinica Sao Francisco Xavier | 45.55571428571428  |  32.383483069526136 |
# |   Altura  | Clinica Geral | Adebola Talib |   Hospital Beatriz Angelo    | 51.14653333333334  |  29.283123840770028 |
# |   Altura  | Clinica Geral | Adebola Talib |     Hospital de Cascais      |      60.5796       |  27.65647158743621  |
# |   Altura  | Clinica Geral | Adebola Talib |   Hospital de Santa Maria    |  51.2327868852459  |  31.47700738269907  |
# |   Altura  | Clinica Geral | Adebola Talib |             None             | 51.82609890109888  |  30.195635055584678 |
# |   Altura  | Clinica Geral |  Adebola Zola |   Hospital Beatriz Angelo    | 47.07279999999999  |  27.287430030449304 |
# |   Altura  | Clinica Geral |  Adebola Zola |   Hospital de Santa Maria    |       62.114       |  23.529694536903786 |
# |   Altura  | Clinica Geral |  Adebola Zola |             None             |      54.5934       |  26.336123993093437 |
# |   Altura  | Clinica Geral |  Lulu Adebola |       Hospital da Luz        | 63.39480000000001  |  29.489632234623294 |
# |   Altura  | Clinica Geral |  Lulu Adebola |     Hospital de Cascais      | 52.996666666666655 |  31.954158779935568 |
# |   Altura  | Clinica Geral |  Lulu Adebola |   Hospital de Santa Maria    | 55.643142857142855 |  25.982734286606625 |
# |   Altura  | Clinica Geral |  Lulu Adebola |             None             | 57.34950617283953  |  28.64864983298666  |
# |   Altura  | Clinica Geral |   Lulu Balu   |       Hospital da Luz        |  47.2609090909091  |  30.674726226828977 |
# |   Altura  | Clinica Geral |   Lulu Balu   |     Hospital de Cascais      | 53.32419354838712  |  30.37323830362987  |
# |   Altura  | Clinica Geral |   Lulu Balu   |   Hospital de Santa Maria    | 59.96185185185185  |  29.633318181377295 |
# |   Altura  | Clinica Geral |   Lulu Balu   |             None             | 54.18312977099237  |  30.20586817883035  |
# |   Altura  | Clinica Geral |   Lulu Eshe   | Clinica Sao Francisco Xavier | 49.23952380952382  |  28.08867734091274  |
# |   Altura  | Clinica Geral |   Lulu Eshe   |   Hospital Beatriz Angelo    | 49.67916666666667  |  29.23362833044025  |
# |   Altura  | Clinica Geral |   Lulu Eshe   |     Hospital de Cascais      | 42.63153846153847  |  27.699273459829758 |
# |   Altura  | Clinica Geral |   Lulu Eshe   |             None             | 46.29714285714285  |  28.107203405971344 |
# |   Altura  | Clinica Geral |   Lulu Nkosi  | Clinica Sao Francisco Xavier | 46.56099999999999  |  28.96417258759881  |
# |   Altura  | Clinica Geral |   Lulu Nkosi  |       Hospital da Luz        |      53.5995       |  31.90514914307885  |
# |   Altura  | Clinica Geral |   Lulu Nkosi  |     Hospital de Cascais      | 57.940000000000005 |  28.977075046679047 |
# |   Altura  | Clinica Geral |   Lulu Nkosi  |             None             |    53.02765625     |  29.818191142171447 |
# |   Altura  | Clinica Geral |   Lulu Nyah   | Clinica Sao Francisco Xavier | 47.172631578947374 |  28.151517985932493 |
# |   Altura  | Clinica Geral |   Lulu Nyah   |       Hospital da Luz        | 58.281578947368416 |  25.589534810403755 |
# |   Altura  | Clinica Geral |   Lulu Nyah   |   Hospital de Santa Maria    | 51.92357142857143  |  29.280165731959325 |
# |   Altura  | Clinica Geral |   Lulu Nyah   |             None             | 52.38621212121212  |  27.840930342830003 |
# |   Altura  | Clinica Geral |   Lulu Penda  |   Hospital Beatriz Angelo    |       40.13        |  27.123184759816674 |
# |   Altura  | Clinica Geral |   Lulu Penda  |       Hospital da Luz        | 58.25727272727272  |  27.90278517960565  |
# |   Altura  | Clinica Geral |   Lulu Penda  |   Hospital de Santa Maria    |       52.824       |  32.126991832577886 |
# |   Altura  | Clinica Geral |   Lulu Penda  |             None             |  48.7178947368421  |  29.458305057183875 |
# |   Altura  | Clinica Geral |   Lulu Simba  | Clinica Sao Francisco Xavier | 52.13411764705882  |  31.314645547016717 |
# |   Altura  | Clinica Geral |   Lulu Simba  |       Hospital da Luz        | 44.318400000000004 |  26.26465506468087  |
# |   Altura  | Clinica Geral |   Lulu Simba  |     Hospital de Cascais      | 40.92142857142857  |  28.643851571622534 |
# |   Altura  | Clinica Geral |   Lulu Simba  |   Hospital de Santa Maria    | 59.40499999999998  |  26.195255977262097 |
# |   Altura  | Clinica Geral |   Lulu Simba  |             None             |  48.9470588235294  |  28.354080911603123 |
# |   Altura  | Clinica Geral |   Lulu Talib  | Clinica Sao Francisco Xavier |      53.77375      |  29.69878855858983  |
# |   Altura  | Clinica Geral |   Lulu Talib  |   Hospital Beatriz Angelo    | 48.466857142857144 |  29.434125030354156 |
# |   Altura  | Clinica Geral |   Lulu Talib  |             None             | 50.62559322033897  |  29.40322632257394  |
# |   Altura  | Clinica Geral |   Lulu Zola   |       Hospital da Luz        | 45.50137931034482  |   26.5627628355585  |
# |   Altura  | Clinica Geral |   Lulu Zola   |     Hospital de Cascais      | 51.85946236559142  |  27.609497671350876 |
# |   Altura  | Clinica Geral |   Lulu Zola   |   Hospital de Santa Maria    | 59.27956521739131  |  29.317439190888802 |
# |   Altura  | Clinica Geral |   Lulu Zola   |             None             | 51.76482758620688  |  27.793015462108677 |
# |   Altura  | Clinica Geral |  Mandla Balu  |   Hospital Beatriz Angelo    |      43.0252       |  31.027643739091758 |
# |   Altura  | Clinica Geral |  Mandla Balu  |       Hospital da Luz        | 48.111875000000005 |  30.24692980976196  |
# |   Altura  | Clinica Geral |  Mandla Balu  |     Hospital de Cascais      | 53.738928571428566 |  27.41931129957237  |
# |   Altura  | Clinica Geral |  Mandla Balu  |             None             | 48.55231884057973  |  29.367714973746228 |
# |   Altura  | Clinica Geral |  Mandla Eshe  |       Hospital da Luz        | 50.667575757575754 |  27.178562787413796 |
# |   Altura  | Clinica Geral |  Mandla Eshe  |   Hospital de Santa Maria    | 36.68090909090908  |  29.409220319021166 |
# |   Altura  | Clinica Geral |  Mandla Eshe  |             None             | 43.67424242424242  |  28.967433016598065 |
# |   Altura  | Clinica Geral |  Mandla Nkosi | Clinica Sao Francisco Xavier | 57.281153846153856 |  26.712869606528326 |
# |   Altura  | Clinica Geral |  Mandla Nkosi |       Hospital da Luz        | 54.194583333333334 |  29.124005633955417 |
# +-----------+---------------+---------------+------------------------------+--------------------+---------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# SELECT nome
# FROM paciente
# JOIN consulta USING (ssn)
# JOIN observacao USING (id)
# WHERE parametro = ‘pressão diastólica’
# AND valor >= 9;

# %%
# %%sql
# DROP INDEX IF EXISTS index_parametro_valor CASCADE;
# DROP INDEX IF EXISTS index_ssn CASCADE;
#
# CREATE INDEX index_parametro_valor
# ON observacao (valor);
#
# CREATE INDEX index_ssn
# ON consulta (ssn);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
# A utilização do index_parametro_valor tem como objetivo otimizar a cláusula 'WHERE', que filtra os resgistos na tabela 'observacao' segundo as condições indicadas. Assim, conseguimos reduzir o número de leituras de disco necessárias, uma vez que a base de dados pode utilizar o índice para encontrar rapidamente os registos desejados.
# Para além do objetivo de otimizar a cláusula 'JOIN', a criação do índice ssn foi criado pois, por ser chave primária de outras entidade, é aconcelhado criar índice.
# Inicialmente, ao testar os tempos do código sem a criação dos índices observámos um execution time de aproximadamente o dobro do que quando fomos testar com os índices, concluindo que os índices efetivamente otimizaram a procura dos dados.
#
# ...

# %% [markdown]
# ### 6.2
# SELECT especialidade, SUM(quantidade) AS qtd
# FROM medico
# JOIN consulta USING (nif)
# JOIN receita USING (codigo_sns)
# WHERE data BETWEEN ‘2023-01-01’ AND ‘2023-12-31’
# GROUP BY especialidade
# ORDER BY qtd;

# %%
# %%sql
# DROP INDEX IF EXISTS index_consulta_nif_data CASCADE;
# DROP INDEX IF EXISTS index_receita_codigo_sns CASCADE;
# DROP INDEX IF EXISTS index_medico_especialidade CASCADE;
#
# CREATE INDEX index_consulta_nif_data
# ON consulta (nif, data, codigo_sns);
#
# CREATE INDEX index_receita_codigo_sns
# ON receita (quantidade);
#
# CREATE INDEX index_medico_especialidade
# ON medico (especialidade);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
# nif: Foi utilizado para a junção entre as tabelas 'consulta' e 'medico'.
#
# data: Foi utilizado na cláusula 'WHERE' para filtrar registos no intervalo de datas.
#
# codigo_sns: Foi utilizado para a junção entre as tabelas 'consulta' e 'receita'.
#
# quantidade: Foi necessário para calcular a soma (SUM(quantidade)) na cláusula 'SELECT'.
#
# especialidade: Foi utilizado na cláusula 'SELECT' e 'GROUP BY'.
#
# ...
